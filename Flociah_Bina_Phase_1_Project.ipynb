# %% [markdown]
# <a href="https://colab.research.google.com/github/Flociah/Phase-One-Project/blob/main/Flociah_Bina_Phase_1_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Final Project Submission
#
#
# Please fill out:
#
# Student name:Flociah Bina
#
# Student pace: part time
#
# Scheduled project review date/time:
#
# Instructor name:Veronicah Isiaho/Samuel Jane
#
# Blog post URL:

# %% [markdown]
# # Business Understanding
# A movie studio is a major entertainment company that makes films also known as film studio. .Movie Studio includes advanced AI features that offer entirely new creative possibilities for your video editing.Creating a new movie studio requires one to define their vision and niche. One has to decide the kinds of films they want to produce and the content one would wish to produce.Microsoft Corporation is an American multinational corporation and technology company best known for its software products.Among the few products are the Windows line of operating systems, the Microsoft 365 suite of productivity applications, the Azure cloud computing platform and the Edge web browser. Microsoft needs to diversify into the creation of the new original content. The main objective is to explore the different types of films which are currently doing the best at the box office and translate them to actionable insights to help decide what types of films to create.

# %% [markdown]
# # Data Understanding
#
# The source of the data is The Movies Database. The Movie Database (TMDB) is a community built movie and TV database.
# Since the year 2008, there has been an increase in number of contributions to the database with over 1,500,000 developers and companies using the platform as TMDB has become a oremier source for metadata.
# The Movie Database is a trusted platform because every single day its services are used by millions of people while processing over 3 billion requests. Hence, it has been proven for years that the data can be trusted and relied on.
#
# In order to understand the type of film to be created, here are some of the features from the database that will help us understand it.
#
# Popularity:  how much that title's page has been visited.
#
# Vote_average: vote average of each movie in a scale of 0 to 10
#
# Vote_count: the total number of votes each movie obtained
#
# Release_date:Date at which it was released in the format "YYYY-DD-MM"
#
# production_budget:Amount of money required for production
#
# worldwide_gross:Total revenue generated from a movie through ticket sales
#
# genres: Types of the movies
#
# release_month:Month released
#
# ROI:Return on Investment (ROI) is a popular profitability metric used to evaluate how well an investment has performed.

# %% [markdown]
# # Data preparation
# The libraries are imported first for structuring of the code effectively. This will also allow reuse of the code while keeping the project maintainable.

# %%
# Importing libraries
import pandas as pd #Importing pandas
import numpy as np #Importing numpy
import matplotlib.pyplot as plt #Importing matplotlib
import seaborn as sns #Importing seaborn

# %% [markdown]
# In order to read our data generated in the format preferred by Excel, it is important to use CSV reader. The pandas read_csvs() function returns a new Dataframe with data and labels from the file data.

# %%
# Reading of the CSV file


df = pd.read_csv('/content/df_final_alex_vj.csv')

# %% [markdown]
# **Checking out for missing data in our dataset**

# %%
# Checking for null values in our dataset
df.isnull().sum()
# Out:
# movie                0
# original_language    0
# popularity           0
# vote_average         0
# vote_count           0
# release_date         0
# production_budget    0
# worldwide_gross      0
# genres               0
# release_month        0
# ROI                  0
# dtype: int64

# %% [markdown]
# There are no missing values in our dataset.

# %% [markdown]
# # Data Analysis

# %%
df
# Out:
#                       movie original_language  popularity  vote_average  \
# 0                   #horror                de       6.099           3.3
# 1       10 cloverfield lane                en      17.892           6.9
# 2     10 days in a madhouse                en       0.955           5.4
# 3                 12 strong                en      13.183           5.6
# 4          12 years a slave                en      16.493           7.9
# ...                     ...               ...         ...           ...
# 1829                 zipper                en       9.373           5.7
# 1830              zookeeper                en      10.764           5.3
# 1831            zoolander 2                en      12.997           4.7
# 1832                   zoom                en       3.434           5.5
# 1833               zootopia                en      27.549           7.7
#
#       vote_count release_date  production_budget  worldwide_gross  \
# ...

# %% [markdown]
# **Summary of the dataset**
#
# The cell below is a summary of our DataFrame. Information displayed by the method includes the total number of entries, rows, columns, datatypes, number of non_null values in each column and the memory used by the dataframe.

# %%
# Summary of the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1834 entries, 0 to 1833
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   movie              1834 non-null   object
#  1   original_language  1834 non-null   object
#  2   popularity         1834 non-null   float64
#  3   vote_average       1834 non-null   float64
#  4   vote_count         1834 non-null   int64
#  5   release_date       1834 non-null   object
#  6   production_budget  1834 non-null   int64
#  7   worldwide_gross    1834 non-null   int64
#  8   genres             1834 non-null   object
#  9   release_month      1834 non-null   int64
#  10  ROI                1834 non-null   int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 157.7+ KB

# %% [markdown]
# **Statistical summary of the dataset**

# %%
# Statistical summary of the data
df.describe()
# Out:
#         popularity  vote_average    vote_count  production_budget  \
# count  1834.000000   1834.000000   1834.000000       1.834000e+03
# mean     10.931178      6.176172   1704.708833       3.834575e+07
# std       8.180437      1.096821   2689.767236       5.200167e+07
# min       0.600000      0.000000      1.000000       9.000000e+03
# 25%       6.110250      5.600000     85.250000       5.000000e+06
# 50%       9.592500      6.200000    653.500000       2.000000e+07
# 75%      14.449750      6.900000   2092.250000       4.600000e+07
# max      80.773000     10.000000  22186.000000       4.250000e+08
#
#        worldwide_gross  release_month           ROI
# count     1.834000e+03    1834.000000  1.834000e+03
# mean      1.190712e+08       6.884406  8.072547e+07
# std       2.226756e+08       3.481343  1.836923e+08
# min       0.000000e+00       1.000000 -1.104502e+08
# 25%       3.287706e+06       4.000000 -1.688551e+06
# 50%       3.668101e+07       7.000000  1.364081e+07
# ...

# %% [markdown]
# **Analysing the dates in the dataset.**

# %%
# Maximum date
df['release_date'].max()
print(f"The maximum date is {df['release_date'].max()}")

#Minimum Date
df['release_date'].min()
print(f"The minimum date is {df['release_date'].min()}")

# Convers release-date to datetime objects
df['release_date'] = pd.to_datetime(df['release_date'])

# Difference between the max and minimum release dates
df['release_date'].max() - df['release_date'].min()

print(f"The difference between the max and minimum release dates is {df['release_date'].max() - df['release_date'].min()}")
# Out:
# The maximum date is 2019-12-31
# The minimum date is 1915-02-08
# The difference between the max and minimum release dates is 38312 days 00:00:00

# %% [markdown]
# In our case of movie release we are working with data from the year 1915-2019.

# %% [markdown]
# **Dominant Language**

# %%
# Most used language
df['original_language'].value_counts().head(2)
# Out:
# original_language
# en    1758
# fr      17
# Name: count, dtype: int64

# %% [markdown]
# English is the language that has been used widely in the film production industry by 1758 users followed by French.

# %% [markdown]
# **Commonly produced genre**

# %%
# The most produced genre
dominant_produced_genre = df['genres'].value_counts().head(1)
print(f"The most produced genre is {highest_produced_genre}")

# Least produced genre
least_produced_genre = df['genres'].value_counts().tail(1)
print(f"The least produced genre is {least_produced_genre}")
# Out:
# The most produced genre is genres
# multiple_genres    1509
# Name: count, dtype: int64
# The least produced genre is genres
# sport    1
# Name: count, dtype: int64

# %% [markdown]
# The most produced genre is the multiple_genres by 1509 while the least produced genre is sport which has only been produced once.

# %% [markdown]
# **Analysis of the production budget and ROI**

# %%
# Comparison of production budget and ROI
df_1 = df.loc[:,["genres","production_budget","ROI"]].sort_values(by='ROI',ascending = False).head(10)
df_1
# Out:
#                genres  production_budget         ROI
# 144            horror          425000000  2351345279
# 146   multiple_genres          300000000  1748134200
# 754   multiple_genres          215000000  1433854864
# 539   multiple_genres          190000000  1328722794
# 1313  multiple_genres          225000000  1292935897
# 208   multiple_genres          200000000  1148258224
# 755   multiple_genres          170000000  1135772799
# 536   multiple_genres          150000000  1122469910
# 176   multiple_genres          160000000  1099199706
# 899   multiple_genres           74000000  1086336173

# %% [markdown]
# The highest production budget is realized in a horror movie by the name Avatar followed by a number of Multiple Genre Movies.

# %%
#Adding a column %ROI, calculating the ROI in percentage
df['%ROI'] = ((df['ROI'] - df['production_budget'])/df['production_budget']*100).head()

print(df[['genres','%ROI']])
# Out:
#                genres         %ROI
# 0     multiple_genres  -200.000000
# 1     multiple_genres  1965.728440
# 2               drama  -199.878200
# 3     multiple_genres     3.195366
# 4     multiple_genres   705.126715
# ...               ...          ...
# 1829  multiple_genres          NaN
# 1830  multiple_genres          NaN
# 1831           comedy          NaN
# 1832  multiple_genres          NaN
# 1833  multiple_genres          NaN
#
# [1834 rows x 2 columns]

# %% [markdown]
# Negative ROI means a losson investment. In our case we can see that multiple genres depending on the movie released in that year has got both negative returns while there is a high cashout. In this case as per out analysis of the first five data analysed, it clearly depicts the fact that some movies had a positive return output while others had a negative return output.

# %% [markdown]
# **Analysis of the release month, popularity and vote count**

# %%
# Most popular released genre
df_2 = df.loc[:,["genres","release_month","popularity","vote_count"]].sort_values(by='popularity',ascending = False).head(10)
df_2
# Out:
#                genres  release_month  popularity  vote_count
# 146   multiple_genres              4      80.773       13948
# 744   multiple_genres             10      78.123       10081
# 1455  multiple_genres             12      53.783        8392
# 1313  multiple_genres              5      50.289       19673
# 588   multiple_genres              8      49.606       17958
# 214   multiple_genres             10      48.571        6679
# 481   multiple_genres             11      48.508        4870
# 1068  multiple_genres             11      48.057        2626
# 1225  multiple_genres              7      46.775       11585
# 831   multiple_genres              3      45.000       12330

# %% [markdown]
# Movies with multiple genres were the most popular with a percentage of 80%.and a vote count of 13948

# %%
# Film with the highest vote_count in comparison to popularity
df_3 = df.loc[:,["genres","popularity","vote_count"]].sort_values(by='vote_count',ascending = False).head(10)
df_3
# Out:
#                genres  popularity  vote_count
# 694   multiple_genres      27.920       22186
# 365   multiple_genres      35.067       20175
# 1313  multiple_genres      50.289       19673
# 144            horror      26.526       18676
# 711   multiple_genres      28.440       18597
# 588   multiple_genres      49.606       17958
# 399   multiple_genres      21.260       15725
# 1462  multiple_genres      14.212       14587
# 854   multiple_genres      28.099       14454
# 717   multiple_genres      32.093       14155

# %% [markdown]
# Multiple genres had the highest vote_count taking the first thre positions in the rank followed by horror in the fourth position.

# %% [markdown]
# **Comparison of the release month and worldwide_gross**

# %%
# month with which movies were mostly released
month_movies_released_most = df['release_month'].mode()
month_movies_released_most
# Out:
# 0    12
# Name: release_month, dtype: int64

# %% [markdown]
# Most movies were released in the month of December

# %%
# Comparison with worldwide_gross
df_4 = df.loc[:,["genres","release_month","worldwide_gross"]].sort_values(by='worldwide_gross',ascending = False).head(10)
df_4
# Out:
#                genres  release_month  worldwide_gross
# 144            horror             12       2776345279
# 146   multiple_genres              4       2048134200
# 754   multiple_genres              6       1648854864
# 539   multiple_genres              4       1518722794
# 1313  multiple_genres              5       1517935897
# 145   multiple_genres              5       1403013963
# 208   multiple_genres              2       1348258224
# 755   multiple_genres              6       1305772799
# 536   multiple_genres             11       1272469910
# 176   multiple_genres              3       1259199706

# %%
# Least worldwide gross
least_worldwide_gross = df.loc[:,["genres","release_month","worldwide_gross"]].sort_values(by='worldwide_gross',ascending = True).tail()
least_worldwide_gross
# Out:
#                genres  release_month  worldwide_gross
# 1313  multiple_genres              5       1517935897
# 539   multiple_genres              4       1518722794
# 754   multiple_genres              6       1648854864
# 146   multiple_genres              4       2048134200
# 144            horror             12       2776345279

# %% [markdown]
# The amount of money raised from the tickets in the month of December was higher followed by the month of April while less tickets were sold in the month of May. This indicates that there was a high revenue generated in the month of December and April while the least revenue was generated in the month of May.

# %%
# world_wide gross value greater than the mean average gross
def worldwide_gross_remarks(worldwide_gross) :
  if worldwide_gross >= df['worldwide_gross'].mean():
    return "Above Average"
  else :
    return "Below Average"
df['worldwide_gross_remarks'] = df['worldwide_gross'].apply(worldwide_gross)
print(df[['genres','worldwide_gross','worldwide_gross_remarks']])
# Out:
#                genres  worldwide_gross worldwide_gross_remarks
# 0     multiple_genres                0           Below Average
# 1     multiple_genres        108286422           Below Average
# 2               drama            14616           Below Average
# 3     multiple_genres         71118378           Below Average
# 4     multiple_genres        181025343           Above Average
# ...               ...              ...                     ...
# 1829  multiple_genres                0           Below Average
# 1830  multiple_genres        170805525           Above Average
# 1831           comedy         55348693           Below Average
# 1832  multiple_genres         12506188           Below Average
# 1833  multiple_genres       1019429616           Above Average
#
# [1834 rows x 3 columns]

# %%
# World-wide gross value counts
df['worldwide_gross_remarks'].value_counts()
# Out:
# worldwide_gross_remarks
# Below Average    1368
# Above Average     466
# Name: count, dtype: int64

# %%
# % worldwide remarks
percentage_worldwide_remarks = (df['worldwide_gross_remarks'].value_counts()/df['worldwide_gross'].value_counts().sum())*100
percentage_worldwide_remarks
# Out:
# worldwide_gross_remarks
# Below Average    74.591058
# Above Average    25.408942
# Name: count, dtype: float64

# %% [markdown]
# Most of the films are below average that is below the mean worldwide gross. The total amout of revenue generated from the films is way below the xpected average.

# %%
# Worldwide gross in comparison to average vote count and and worldwide gross remaks
df_5 = df.loc[:,["movie","genres","vote_average","worldwide_gross_remarks","release_month"]].sort_values(by='vote_average',ascending = False).head(10)
df_5
# Out:
#                 movie           genres  vote_average worldwide_gross_remarks  \
# 378         departure  multiple_genres          10.0           Below Average
# 152       bad company         thriller          10.0           Below Average
# 290      chemical cut            drama          10.0           Below Average
# 709          insomnia            drama          10.0           Below Average
# 572             grace  multiple_genres          10.0           Below Average
# 231         book club      documentary          10.0           Below Average
# 988   out of the blue  multiple_genres          10.0           Below Average
# 1000         paranoia            drama          10.0           Below Average
# 951              nine           horror           9.0           Below Average
# 446        el chicano            drama           9.0           Below Average
#
#       release_month
# 378               3
# 152               6
# 290              12
# 709               5
# ...

# %% [markdown]
# In a scale of 1 to 10, only 8 have the highest average vote in all the years. All the movies with a vote_average of 10 are below the average of worldwide gross. We also notice that December has a vote average of 10 considering the high number of mocies produced.

# %%
# Correlation of our datasets.
correlation = df.corr(numeric_only = True)
correlation
# Out:
#                    popularity  vote_average  vote_count  production_budget  \
# popularity           1.000000      0.327974    0.717182           0.590268
# vote_average         0.327974      1.000000    0.353992           0.152008
# vote_count           0.717182      0.353992    1.000000           0.639593
# production_budget    0.590268      0.152008    0.639593           1.000000
# worldwide_gross      0.596561      0.223752    0.750794           0.800799
# release_month        0.039393      0.073230    0.039065           0.009345
# ROI                  0.556064      0.228204    0.729064           0.687654
# %ROI                 0.774643      0.651415    0.732008          -0.244739
#
#                    worldwide_gross  release_month       ROI      %ROI
# popularity                0.596561       0.039393  0.556064  0.774643
# vote_average              0.223752       0.073230  0.228204  0.651415
# vote_count                0.750794       0.039065  0.729064  0.732008
# ...

# %% [markdown]
# # Data Visualization

# %% [markdown]
# Visualizing the number of movies per genre using a bar graph.

# %%
# Movies per genre
plt.figure(figsize=(10, 6))
df['genres'].value_counts().plot(kind='bar')
plt.title('Number of Movies per Genre')
plt.xlabel('Genre')
plt.ylabel('Number of Movies')
plt.savefig('number_of_movies_per_genre.png')
plt.show()

# %% [markdown]
# The number of movies under multiple genres were many followed by drama and comedy. The least genres produced are the sports, followed by romance and music genres.

# %% [markdown]
# **Visualizing the best language for the film**

# %%
# Data visualization

x = df['original_language']
y= df['popularity']
fig, ax = plt.subplots(figsize=(12,10))
plt.bar(x,y, color='green')
plt.xticks(rotation=45)
plt.title('MOVIE PROFITABILITY BASED ON LANGUAGE AND POPULARITY')
plt.xlabel('original_language')
plt.ylabel('popularity')
plt.savefig('movie_profitability_based_on_language_and_popularity.png')
plt.show()

# %% [markdown]
# The most dominant language is English followed by french.

# %% [markdown]
# **Visualizing correlations**

# %%
sns.heatmap(correlation, annot=True)
plt.rcParams['figure.figsize'] = (10, 10)  # Set the figure size
plt.title('Correlation Heatmap')
plt.savefig('correlation_heatmap.png')
plt.show()

# %% [markdown]
# **Visualizing central measures of tendency**

# %%
# Box plot visuals of ROI by Genre
plt.figure(figsize=(20, 5)) # Increasing the size of the box plot.
sns.boxplot(x='genres', y='ROI', data=df)
plt.title('Box Plot of ROI by Genre')
plt.xlabel('Genre')
plt.ylabel('ROI')
plt.savefig('box_plot_roi_by_genre.png')
plt.show()

# %% [markdown]
# This is a box plot that shows how the genre is related to the Return Output Investment. As per the box plot, there are outliers and there is need to get rid of outliers to get accurate values

# %%
# Boxplot without outliers
plt.figure(figsize=(20, 10))
sns.boxplot(x='genres', y='ROI', data=df, showfliers=False)
plt.title('Box Plot of ROI by Genre (Without Outliers)')
plt.xlabel('Genre')
plt.ylabel('ROI')
plt.savefig('box_plot_roi_by_genre_without_outliers.png')
plt.show()

# %% [markdown]
# **Visualizing of the product budget and ROI**

# %%
sns.scatterplot(x='production_budget', y='ROI', data=df)
plt.title('Scatter Plot of Production Budget vs ROI')
plt.xlabel('Production Budget')
plt.ylabel('ROI')
plt.savefig('scatter_plot_production_budget_roi.png')
plt.show()

# %% [markdown]
# **Visualizing film with the highest vote count to popularity**

# %%
sns.stripplot(x='vote_count', y='popularity', data=df, color= 'Green')
plt.title('Scatter Plot of Vote Count vs Popularity')
plt.xlabel('Vote Count')
plt.ylabel('Popularity')
plt.savefig('scatter_plot_vote_count_popularity.png')
plt.show()

# %% [markdown]
# **Visualizing worldwide Gross in comparison to the release month.**

# %%
sns.barplot(x='release_month', y='worldwide_gross', data=df, color='Brown', edgecolor= 'Black')
plt.title('Bar Plot of Worldwide Gross by Release Month')
plt.xlabel('Release Month')
plt.ylabel('Worldwide Gross')
plt.savefig('bar_plot_worldwide_gross_by_release_month.png')
plt.show()

# %% [markdown]
# **Worldwide gross in comparison to vote average**

# %%
sns.scatterplot(x='vote_average', y='worldwide_gross', data=df, color='Purple', edgecolor= 'Black')
plt.title('Bar Plot of Worldwide Gross by Vote Average')
plt.xlabel('Vote Average')
plt.ylabel('Worldwide Gross')
plt.savefig('bar_plot_worldwide_gross_by_vote_average.png')
plt.show()

# %% [markdown]
# **Visualizing month in relation to worldwide gross.**

# %% [markdown]
# # Conclusion.
# From the analysis done we can deduce that:
#
#
# 1. **Language of production.**
#
#  English is the leading language used in the film production followed by french.
#
# 2. **Genre**
#
#  The most produced film genre is multiple genres by 1509 counts while the least produced is genre sport.
# 3. **Budget versus the Return output Investment**
#
#  One movie in the horror genre tends to have the highest budget and a high Return Output Investment followed by Multiple Genres.
#
# 4. **Release Month**
#
#   December is the most popular month for movie release and has the highest vote counts.
# 5. **Worldwide gross in comparison to month.**
#
#  More revenue is generated in the month of December where most movies are usually released.

# %% [markdown]
# # Recommendations.
# As per the analysis done, I would recommend Microsoft to consider the multiple genre movie as it is the most filmed with the highest vote_counts and have shown to consisently perform well at the box office.
#
# Most of the films to be produced should be in English as their original language and a second language which is French due to the highest number of people watching in the two sets of languages.
#
# In terms of the return output, I would recommend multiple genres despite horror having the highest ouput. This is because of the lower budget that returns a high return.
# I would recommend release of movies in the month of December due to a high vote_average and a high revenue generated in the month of December.
